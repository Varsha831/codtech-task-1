# %% [markdown]
# <a href="https://colab.research.google.com/github/Varsha831/codtech-task-1/blob/main/Untitled23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("iris_csv (1).csv")

# %%
df.head()
# Out:
#    sepallength  sepalwidth  petallength  petalwidth        class
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
df.tail()
# Out:
#      sepallength  sepalwidth  petallength  petalwidth           class
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sepallength  150 non-null    float64
#  1   sepalwidth   150 non-null    float64
#  2   petallength  150 non-null    float64
#  3   petalwidth   150 non-null    float64
#  4   class        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        sepallength  sepalwidth  petallength  petalwidth
# count   150.000000  150.000000   150.000000  150.000000
# mean      5.843333    3.054000     3.758667    1.198667
# std       0.828066    0.433594     1.764420    0.763161
# min       4.300000    2.000000     1.000000    0.100000
# 25%       5.100000    2.800000     1.600000    0.300000
# 50%       5.800000    3.000000     4.350000    1.300000
# 75%       6.400000    3.300000     5.100000    1.800000
# max       7.900000    4.400000     6.900000    2.500000

# %%
df.shape
# Out:
# (150, 5)

# %%
df.isnull()
# Out:
#      sepallength  sepalwidth  petallength  petalwidth  class
# 0          False       False        False       False  False
# 1          False       False        False       False  False
# 2          False       False        False       False  False
# 3          False       False        False       False  False
# 4          False       False        False       False  False
# ..           ...         ...          ...         ...    ...
# 145        False       False        False       False  False
# 146        False       False        False       False  False
# 147        False       False        False       False  False
# 148        False       False        False       False  False
# 149        False       False        False       False  False
#
# [150 rows x 5 columns]

# %%
df.head(1)
# Out:
#    sepallength  sepalwidth  petallength  petalwidth        class
# 0          5.1         3.5          1.4         0.2  Iris-setosa

# %%
df.tail(1)
# Out:
#      sepallength  sepalwidth  petallength  petalwidth           class
# 149          5.9         3.0          5.1         1.8  Iris-virginica

# %%
df.columns
# Out:
# Index(['sepallength', 'sepalwidth', 'petallength', 'petalwidth', 'class'], dtype='object')

# %%
df.nunique()
# Out:
# sepallength    35
# sepalwidth     23
# petallength    43
# petalwidth     22
# class           3
# dtype: int64

# %%
df['sepallength'].unique()
# Out:
# array([5.1, 4.9, 4.7, 4.6, 5. , 5.4, 4.4, 4.8, 4.3, 5.8, 5.7, 5.2, 5.5,
#        4.5, 5.3, 7. , 6.4, 6.9, 6.5, 6.3, 6.6, 5.9, 6. , 6.1, 5.6, 6.7,
#        6.2, 6.8, 7.1, 7.6, 7.3, 7.2, 7.7, 7.4, 7.9])

# %%
df['class'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df.isnull().sum()
# Out:
# sepallength    0
# sepalwidth     0
# petallength    0
# petalwidth     0
# class          0
# dtype: int64

# %%
import pandas as pd
import requests
from io import BytesIO

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
response = requests.get(url)
iris_web = pd.read_csv(BytesIO(response.content), header=None,
names=['sepal_length2', 'sepal_width', 'petal_length', 'petal_width', 'species'])

# %%
print(iris_web.head())
# Out:
#    sepal_length2  sepal_width  petal_length  petal_width      species
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa

# %%
print('Descriptive statistics for Iris dataset:')
print(iris_web.describe())
# Out:
# Descriptive statistics for Iris dataset:
#        sepal_length2  sepal_width  petal_length  petal_width
# count     150.000000   150.000000    150.000000   150.000000
# mean        5.843333     3.054000      3.758667     1.198667
# std         0.828066     0.433594      1.764420     0.763161
# min         4.300000     2.000000      1.000000     0.100000
# 25%         5.100000     2.800000      1.600000     0.300000
# 50%         5.800000     3.000000      4.350000     1.300000
# 75%         6.400000     3.300000      5.100000     1.800000
# max         7.900000     4.400000      6.900000     2.500000

# %%
print('\nMean values for each species:')
print(iris_web.groupby('species').mean()) # Use 'species' as a string to reference the column
# Out:
# Mean values for each species:
#                  sepal_length2  sepal_width  petal_length  petal_width
# species
# Iris-setosa              5.006        3.418         1.464        0.244
# Iris-versicolor          5.936        2.770         4.260        1.326
# Iris-virginica           6.588        2.974         5.552        2.026

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
flights = sns.load_dataset('flights')
flights.head()
april_flights = flights.query('month == "May"') # Pass the condition as a string
sns.lineplot(data=april_flights, x='year', y='passengers')
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
iris= sns.load_dataset('iris')
sns.kdeplot(data =iris)
# Out:
# <Axes: ylabel='Density'>

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(-3.0, 3.0, 0.1)
y = np.arange(-3.0, 3.0, 0.1)
X, Y = np.meshgrid(x, y)
Z = np.sin(X)*np.cos(Y)
fig, ax = plt.subplots(figsize=(6,6))
ax.contour(X,Y,Z)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(-3.0, 3.0, 0.1)
y = np.arange(-3.0, 3.0, 0.1)
X, Y = np.meshgrid(x, y)
Z = np.sin(X)*np.cos(Y)
fig, ax = plt.subplots(figsize=(6,6))
ax.contourf(X,Y,Z)
plt.show()

# %%
import pandas as pd
from sklearn.datasets import load_diabetes
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv('/content/iris_csv (1).csv')
df
# Out:
#      sepallength  sepalwidth  petallength  petalwidth           class
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
import pandas as pd

# Assuming 'df' is your DataFrame
# Select only the numerical columns for correlation calculation
numerical_df = df.select_dtypes(include=['number'])

# Calculate the correlation matrix
corr = numerical_df.corr(method='pearson')

print(corr)
# Out:
#              sepallength  sepalwidth  petallength  petalwidth
# sepallength     1.000000   -0.109369     0.871754    0.817954
# sepalwidth     -0.109369    1.000000    -0.420516   -0.356544
# petallength     0.871754   -0.420516     1.000000    0.962757
# petalwidth      0.817954   -0.356544     0.962757    1.000000

# %%
c = np.corrcoef(df['sepallength'],df['petallength'])
print('Correlations between sepallength and  petallength\n',c)
# Out:
# Correlations between sepallength and  petallength
#  [[1.         0.87175416]
#  [0.87175416 1.        ]]

# %%
plt.figure(figsize=(10,8), dpi =500)
sns.heatmap(corr,annot=True,fmt='.2f', linewidth=.5)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your data is in the DataFrame 'df' from previous cells
plt.scatter(df['sepallength'], df['sepalwidth'])  # Use 'df' instead of 'dataset'
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.title('Scatter Plot of Sepal Length vs Sepal Width')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your data is in the DataFrame 'df' from previous cells
plt.hist(df['sepallength'], bins=10)  # Changed 'dataset' to 'df' and 'sepal-length' to 'sepallength'
plt.xlabel('Sepal Length')
plt.ylabel('Frequency')
plt.title('Histogram of Sepal Length')
plt.show()
